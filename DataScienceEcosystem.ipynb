# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:7242b9f3-abad-4c6c-9305-fa8dda190d8f.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:86ed6fa3-cfe4-4528-a3b6-7c42e8f7e38f.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# * python
# * the R statistical language
# * Julia

# %% [markdown]
# ![4-dslanguages.png](attachment:7aac8737-e519-4c0a-921d-97bda16ff99c.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# * Pandas
# * Numpy
# * Scipy

# %% [markdown]
# ![5-dslibraries.png](attachment:68d8d66c-d782-4810-90ca-10e8a4f74ed2.png)

# %% [markdown]
# <table>
#   <tr>
#     <th>Data Science Tools</th>
#   </tr>
#   <tr>
#     <td>SAS</td>
#       </tr>
#       <tr>
#     <td>Apache Spark</td>
#          </tr>
#     <tr>
#     <td>BigML</td>
#   </tr>
# </table>

# %% [markdown]
# ![6-dstools.png](attachment:9ffe92a6-3518-4f76-abe7-cdaa819f6db2.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
(3*4)+5
#This a simple arithmetic expression to mutiply then add integers

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:4314f1b1-8df2-4e93-a447-8977427230d0.png)

# %% [markdown]
# # This will convert 200 minutes to hours by diving by 60

# %%
200/60
